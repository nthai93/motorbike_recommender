# %%
import shutil

# Tạo file zip đúng chuẩn (không dùng zipfile nén pickle)
shutil.make_archive("tfidf_index_index", 'zip', root_dir=".", base_dir="tfidf_index.index")
print("✅ Đã tạo tfidf_index_index.zip thành công")
# Out:
# ✅ Đã tạo tfidf_index_index.zip thành công
